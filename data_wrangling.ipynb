# %% [markdown]
# # Initializing Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading datasets

# %%
df = pd.read_csv("penguins_lter.csv")
df2 = pd.read_csv("penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# # Displaying the tail of the csv

# %%
df.tail()
# Out:
#     studyName  Sample Number                            Species  Region  \
# 339   PAL0910            120  Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121  Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122  Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123  Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124  Gentoo penguin (Pygoscelis papua)  Anvers
#
#      Island               Stage Individual ID Clutch Completion  Date Egg  \
# 339  Biscoe  Adult, 1 Egg Stage         N38A2                No   12/1/09
# 340  Biscoe  Adult, 1 Egg Stage         N39A1               Yes  11/22/09
# 341  Biscoe  Adult, 1 Egg Stage         N39A2               Yes  11/22/09
# 342  Biscoe  Adult, 1 Egg Stage         N43A1               Yes  11/22/09
# 343  Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
#      Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# ...

# %% [markdown]
# # # Display info of the csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %% [markdown]
# # Describing csv file

# %%
df.describe()
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          342.000000         342.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.459584           1.974793
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.225000          15.600000
# 50%        58.000000           44.450000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           342.000000     342.000000         330.000000
# mean            200.915205    4201.754386           8.733382
# std              14.061714     801.954536           0.551770
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.299890
# ...

# %% [markdown]
# # Conducting a null search and summing up every available null values present in each column

# %%
df.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %% [markdown]
# # Setting option for max rows

# %%
pd.set_option("display.max_rows", 5)

df
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0    Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1    Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# ..         ...                 ...           ...               ...       ...
# 342     Biscoe  Adult, 1 Egg Stage         N43A1               Yes  11/22/09
# 343     Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
# ...

# %% [markdown]
# # Melting the csv

# %%
df.melt()
# Out:
#       variable   value
# 0       Gender    MALE
# 1       Gender  FEMALE
# ...        ...     ...
# 5846  Comments     NaN
# 5847  Comments     NaN
#
# [5848 rows x 2 columns]

# %% [markdown]
# # pivotting the csv

# %%
df.pivot(columns = "Individual ID")
# Out:
#               Gender                                                         \
# Individual ID N100A1 N100A2 N10A1 N10A2 N11A1 N11A2 N12A1 N12A2 N13A1 N13A2
# 0                NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1                NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ..               ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 342              NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 343              NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                ... Comments                                                 \
# Individual ID  ...    N95A1 N95A2 N96A1 N96A2 N98A1 N98A2 N99A1 N99A2 N9A1
# 0              ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 1              ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# ..             ...      ...   ...   ...   ...   ...   ...   ...   ...  ...
# ...

# %% [markdown]
# # merging two similar datasets

# %%
merged_table = df.merge(df2, left_on="Culmen Length (mm)", right_on="culmen_length_mm")

merged_table
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 958   PAL0910            118    Gentoo penguin (Pygoscelis papua)  Anvers
# 959   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0    Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1    Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# ..         ...                 ...           ...               ...       ...
# 958     Biscoe  Adult, 1 Egg Stage         N36A2               Yes   12/1/09
# 959     Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
# ...

# %% [markdown]
# # Using apply function

# %%
merged_table.apply(print)
# Out:
# 0      PAL0708
# 1      PAL0708
#         ...
# 958    PAL0910
# 959    PAL0910
# Name: studyName, Length: 960, dtype: object
# 0        1
# 1        2
#       ...
# 958    118
# 959    124
# Name: Sample Number, Length: 960, dtype: int64
# 0      Adelie Penguin (Pygoscelis adeliae)
# 1      Adelie Penguin (Pygoscelis adeliae)
#                       ...
# 958      Gentoo penguin (Pygoscelis papua)
# 959      Gentoo penguin (Pygoscelis papua)
# Name: Species, Length: 960, dtype: object
# 0      Anvers
# 1      Anvers
#         ...
# 958    Anvers
# 959    Anvers
# Name: Region, Length: 960, dtype: object
# 0      Torgersen
# 1      Torgersen
#          ...
# 958       Biscoe
# 959       Biscoe
# Name: Island, Length: 960, dtype: object
# 0      Adult, 1 Egg Stage
# 1      Adult, 1 Egg Stage
#               ...
# 958    Adult, 1 Egg Stage
# 959    Adult, 1 Egg Stage
# Name: Stage, Length: 960, dtype: object
# 0       N1A1
# 1       N1A2
#        ...
# 958    N36A2
# 959    N43A2
# ...

# %% [markdown]
# # Using applymap() function

# %%
merged_table.applymap(lambda x: x * 2)
# Out:
# C:\Users\Felix Ferdinad\AppData\Local\Temp\ipykernel_3016\4280552711.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   merged_table.applymap(lambda x: x * 2)
#           studyName  Sample Number  \
# 0    PAL0708PAL0708              2
# 1    PAL0708PAL0708              4
# ..              ...            ...
# 958  PAL0910PAL0910            236
# 959  PAL0910PAL0910            248
#
#                                                Species        Region  \
# 0    Adelie Penguin (Pygoscelis adeliae)Adelie Peng...  AnversAnvers
# 1    Adelie Penguin (Pygoscelis adeliae)Adelie Peng...  AnversAnvers
# ..                                                 ...           ...
# 958  Gentoo penguin (Pygoscelis papua)Gentoo pengui...  AnversAnvers
# 959  Gentoo penguin (Pygoscelis papua)Gentoo pengui...  AnversAnvers
#
#                  Island                                 Stage Individual ID  \
# ...

# %% [markdown]
# # Query usage in merged table

# %%
merged_table.query("`Culmen Length (mm)` > 40")
# Out:
#     studyName  Sample Number                              Species  Region  \
# 10    PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11    PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 958   PAL0910            118    Gentoo penguin (Pygoscelis papua)  Anvers
# 959   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# 10   Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 11   Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# ..         ...                 ...           ...               ...       ...
# 958     Biscoe  Adult, 1 Egg Stage         N36A2               Yes   12/1/09
# 959     Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
# ...

# %% [markdown]
# # Renaming the columns

# %%
merged_table.rename(columns = {"Stage": "Development Cycle"}, inplace = True)

merged_table
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 958   PAL0910            118    Gentoo penguin (Pygoscelis papua)  Anvers
# 959   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island   Development Cycle Individual ID Clutch Completion  Date Egg  \
# 0    Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1    Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# ..         ...                 ...           ...               ...       ...
# 958     Biscoe  Adult, 1 Egg Stage         N36A2               Yes   12/1/09
# 959     Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
# ...

# %% [markdown]
# # Setting and resetting index

# %%
merged_table.set_index("Sex", inplace= True)
merged_table.index.name = "Gender"
merged_table.reset_index(inplace= True)

merged_table
# Out:
#      Gender studyName  Sample Number                              Species  \
# 0      MALE   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)
# 1    FEMALE   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)
# ..      ...       ...            ...                                  ...
# 958    MALE   PAL0910            118    Gentoo penguin (Pygoscelis papua)
# 959    MALE   PAL0910            124    Gentoo penguin (Pygoscelis papua)
#
#      Region     Island   Development Cycle Individual ID Clutch Completion  \
# 0    Anvers  Torgersen  Adult, 1 Egg Stage          N1A1               Yes
# 1    Anvers  Torgersen  Adult, 1 Egg Stage          N1A2               Yes
# ..      ...        ...                 ...           ...               ...
# 958  Anvers     Biscoe  Adult, 1 Egg Stage         N36A2               Yes
# 959  Anvers     Biscoe  Adult, 1 Egg Stage         N43A2               Yes
#
#      Date Egg  ...  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# ...

# %% [markdown]
# # Displaying a groupby function

# %%
merged_table.groupby(["Sample Number"]).count()
# Out:
#                studyName  Species  Region  Island  Stage  Individual ID  \
# Sample Number
# 1                      9        9       9       9      9              9
# 2                     13       13      13      13     13             13
# ...                  ...      ...     ...     ...    ...            ...
# 151                    4        4       4       4      4              4
# 152                    2        2       2       2      2              2
#
#                Clutch Completion  Date Egg  Culmen Length (mm)  \
# Sample Number
# 1                              9         9                   9
# 2                             13        13                  13
# ...                          ...       ...                 ...
# 151                            4         4                   4
# 152                            2         2                   2
#
#                Culmen Depth (mm)  ...  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# Sample Number                     ...
# ...

# %% [markdown]
# # Aggregating the max value of the column = "culmen_length_mm"

# %%
merged_table.agg({"culmen_length_mm" : ['max']})
# Out:
#      culmen_length_mm
# max              59.6

# %% [markdown]
# # Dropping null values

# %%
merged_table.dropna()
# Out:
#     studyName  Sample Number                              Species  Region  \
# 23    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 24    PAL0708              7  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 455   PAL0910            131  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 456   PAL0910            132  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# 23   Torgersen  Adult, 1 Egg Stage          N4A1                No  11/15/07
# 24   Torgersen  Adult, 1 Egg Stage          N4A1                No  11/15/07
# ..         ...                 ...           ...               ...       ...
# 455  Torgersen  Adult, 1 Egg Stage         N73A1                No  11/23/09
# 456  Torgersen  Adult, 1 Egg Stage         N73A2                No  11/23/09
#
# ...

# %% [markdown]
# # Filling null values with other strings

# %%
merged_table.fillna(value = {"Comments" : "Unrated", "Delta 15 N (o/oo)" : "Unrated", "Delta 13 C (o/oo)" : "Unrated"})
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 958   PAL0910            118    Gentoo penguin (Pygoscelis papua)  Anvers
# 959   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0    Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1    Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# ..         ...                 ...           ...               ...       ...
# 958     Biscoe  Adult, 1 Egg Stage         N36A2               Yes   12/1/09
# 959     Biscoe  Adult, 1 Egg Stage         N43A2               Yes  11/22/09
#
# ...

# %% [markdown]
# # Using simple imputter to fill the dataframe

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='constant')
columns_with_missing_values = df2.columns[df2.isnull().any()].tolist()
df2[columns_with_missing_values] = imputer.fit_transform(df2[columns_with_missing_values])
print(df2.isnull().sum())
# Out:
# species        0
# island         0
#               ..
# body_mass_g    0
# sex            0
# Length: 7, dtype: int64
